# %%
# Automation Launcher — interfaz de Voila
#
# Este notebook es a proposito de cinco lineas. Toda la logica vive en el
# paquete `automation_launcher/`, en archivos .py que git puede comparar,
# pytest puede probar y una persona puede revisar en un pull request.
#
# Para correr:   voila app.ipynb
# Para el demo:  ./run_local.sh   (o run_local.bat en Windows)

from automation_launcher.ui.app import run

run()
