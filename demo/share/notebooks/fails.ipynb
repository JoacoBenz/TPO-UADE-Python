# %%
# Falla a proposito: el tablero tiene que marcarlo en rojo.
print("Buscando el archivo del custodio...")

# %%
ruta = "/mnt/custodio/posiciones_20260904.csv"
raise FileNotFoundError(f"no se encontro {ruta}. Reviso si llego el archivo de las 18:00?")
