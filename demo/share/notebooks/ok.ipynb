# %%
# Proceso que termina bien.
import time

print("Conectando al origen de datos...")
time.sleep(0.4)

# %%
registros = 1204
for lote in range(1, 5):
    print(f"Lote {lote}/4 procesado ({registros // 4} registros)")
    time.sleep(0.2)

# %%
print(f"Listo: {registros} registros, 0 errors")
