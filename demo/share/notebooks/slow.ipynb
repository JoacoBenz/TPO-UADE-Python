# %%
# Corre ~60s: sirve para probar el boton Stop y el cronometro en vivo.
import time

print("Revaluando cartera. Esto tarda un rato — proba el Stop.")

# %%
for i in range(60):
    print(f"  [{i+1:>2}/60] revaluando posiciones...")
    time.sleep(1)
print("Revaluacion completa")
