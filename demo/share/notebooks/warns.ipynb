# %%
# Termina con advertencias: el tablero lo marca en ambar, no en rojo.
import warnings

print("Iniciando conciliacion...")
warnings.warn("El archivo del custodio llego 40 minutos tarde", UserWarning)

# %%
print("Conciliacion terminada con 1 advertencia")
